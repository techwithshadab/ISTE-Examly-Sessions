# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# This line is only for jupyter notebooks, for another editor, simply we use: **plt.show()** at the end of all your plotting commands to have the figure pop up in another window.

# %% [markdown]
# ### Basic plot

# %%
x = np.arange(1,10)
y = x ** 2

# %%
plt.plot(x, y, 'r')

# %%
plt.plot(x, y, 'r')
plt.title('any Title')
# Out:
# Text(0.5, 1.0, 'any Title')

# %%
plt.plot(x, y, 'r')
plt.title('any Title')
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
# Out:
# Text(0, 0.5, 'Y Axis Label')

# %% [markdown]
# #### Customizing figure height and width

# %%
fig = plt.figure(figsize = (12,8))
plt.plot(x, y, 'r')
plt.title('any Title')
plt.xlabel('X Axis Label')
plt.ylabel('Y Axis Label')
# Out:
# Text(0, 0.5, 'Y Axis Label')

# %% [markdown]
# #### Saving the visualization output

# %%
fig.savefig("first.png")

# %%
cars = pd.read_csv("cars93.csv")
cars.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %% [markdown]
# ### Box Plot

# %%
fig = plt.figure(figsize = (12,8))
plt.boxplot(cars["Price"])
plt.title("Boxplot of Price")
plt.show()

# %%
B = plt.boxplot(cars["Price"])
[item.get_ydata()[1] for item in B['whiskers']]
# Out:
# [7.4, 38.0]

# %%
fig = plt.figure(figsize = (12,8))
plt.boxplot(cars["Horsepower"])
plt.title("Boxplot of Horsepower")
plt.show()

# %%
# using Pandas
cars["Horsepower"].plot.box(figsize = (10,7))
plt.show()

# %% [markdown]
# ### Histogram

# %%
a = np.arange(17)
plt.scatter(a, np.zeros_like(a))

# %%
plt.scatter(cars["Horsepower"], np.zeros_like(cars["Horsepower"]))
plt.show()

# %%
plt.hist(cars["Horsepower"])
plt.title("Histogram of Horsepower")
plt.show()

# %%
plt.hist(cars["Horsepower"], bins = 16)
plt.title("Histogram of Horsepower")
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
cars["Type"].value_counts()
# Out:
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: Type, dtype: int64

# %%
plt.bar(cars["Type"].value_counts().index, cars["Type"].value_counts().values)
plt.xlabel("Type")
plt.ylabel("Count")
plt.title("Distribution of Type across various categories")
plt.show()

# %%
plt.bar(cars["Type"].values, cars["MPG.city"],width=0.2,label="Mileage in city")
plt.xlabel("Type")
plt.ylabel("MPG.city")
plt.title("MPG.city across the car types")
plt.show()

# %%
grouped_df = cars.groupby("Type").mean()
grouped_df
# Out:
#              Price   MPG.city  Horsepower  Passengers  Rear.seat.room  \
# Type
# Compact  18.212500  22.687500  131.000000    5.062500       27.937500
# Large    24.300000  18.363636  179.454545    6.000000       31.454545
# Midsize  27.218182  19.545455  173.090909    5.136364       28.568182
# Small    10.166667  29.857143   91.000000    4.619048       26.452381
# Sporty   19.392857  21.785714  160.142857    3.714286       23.416667
# Van      19.100000  17.000000  149.444444    7.111111       30.500000
#
#          Luggage.room
# Type
# Compact     13.687500
# Large       18.272727
# Midsize     15.000000
# Small       12.000000
# Sporty      11.416667
# Van               NaN

# %%
grouped_df.reset_index(inplace = True)

# %%
plt.bar(grouped_df["Type"], grouped_df["MPG.city"])
plt.xlabel("Type")
plt.ylabel("MPG.city")
plt.title("MPG.city mean across the car types")
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
plt.scatter(cars["Horsepower"], cars["MPG.city"])
plt.xlabel("Horsepower")
plt.ylabel("MPG.city")
plt.title("Scatter plot of Horsepower vs. MPG.city")
plt.show()

# %%
plt.scatter(cars["Horsepower"], cars["MPG.city"], c = "r",marker = "*")
plt.xlabel("Horsepower")
plt.ylabel("MPG.city")
plt.title("Scatter plot of Horsepower vs. MPG.city")
plt.show()

# %% [markdown]
# ### Line Chart

# %%
plt.plot(cars["Horsepower"], cars["MPG.city"])

# %%
cars93_ordered = cars.sort_values(by = "Horsepower") 
cars93_ordered.head()
# Out:
#    Manufacturer    Model   Type  Price  MPG.city      AirBags  Horsepower  \
# 38          Geo    Metro  Small    8.4        46  Driver only          55
# 30         Ford  Festiva  Small    7.4        31  Driver only          63
# 82       Suzuki    Swift  Small    8.6        39          NaN          70
# 79       Subaru    Justy  Small    8.4        33          NaN          73
# 72      Pontiac   LeMans  Small    9.0        31          NaN          74
#
#     Passengers  Rear.seat.room  Luggage.room
# 38           4            27.5          10.0
# 30           4            26.0          12.0
# 82           4            27.5          10.0
# 79           4            23.5          10.0
# 72           4            25.5          17.0

# %%
plt.plot(cars93_ordered["Horsepower"], cars93_ordered["MPG.city"])
plt.xlabel("Horsepower")
plt.ylabel("MPG.city")
plt.title("Line chart of Horsepower vs. MPG.city")
# Out:
# Text(0.5, 1.0, 'Line chart of Horsepower vs. MPG.city')
