# %% [markdown]
# #### Refer to the same ais.csv(Australian Athelets dataset). Plot the below curves/charts using Seaborn.
#
# ### Question 1.
#
# #### Plot the PDF(distribution) of rcc based on sex, as shown below.

# %% [markdown]
# ### Question 2.
#
# #### Plot the CDF of rcc based on Sex, as shown below.

# %% [markdown]
# #### Question 3.
#
# #### Plot the distribution of sex, as shown below

# %% [markdown]
# ### Question 4
#
# Suppose that **carbon monoxide(CO) strength** in air follows a **normal distribution** with **mean 94** and **standard deviation 5**.
#
# #### a. What is the probability that the CO strength equals 98?

# %%
# Out:
# 0.05793831055229655

# %% [markdown]
# #### b. What is the probability that CO strength is at most 102?

# %%
# Out:
# 0.945200708300442

# %% [markdown]
# #### c. What is the probability that CO strength is at least 100?

# %%
# Out:
# 0.11506967022170822

# %% [markdown]
# #### d. What is the probability that CO strength differs from the mean value by at most 1.5 standard deviations?

# %%
# Out:
# 0.8663855974622838
