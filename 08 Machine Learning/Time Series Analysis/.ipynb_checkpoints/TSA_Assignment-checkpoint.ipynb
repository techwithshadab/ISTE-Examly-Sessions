# %% [markdown]
# #### Refer to the DailyTotalFemaleBirths.csv dataset and perform following set of tasks.
#
# #### Q1. Import the dataset and also set index_col to Date, as shown below.

# %%
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %% [markdown]
# #### Q2. Visualize this time series data as shown below.

# %% [markdown]
# #### Q3. Perform the Simple moving average of period 6 and 12. Add them to the dataframe as shown below.

# %%
# Out:
#             Births  6_period_SMA  12_period_SMA
# Date
# 1959-01-01      35           NaN            NaN
# 1959-01-02      32           NaN            NaN
# 1959-01-03      30           NaN            NaN
# 1959-01-04      31           NaN            NaN
# 1959-01-05      44           NaN            NaN
# 1959-01-06      29     33.500000            NaN
# 1959-01-07      45     35.166667            NaN
# 1959-01-08      43     37.000000            NaN
# 1959-01-09      38     38.333333            NaN
# 1959-01-10      27     37.666667            NaN
# 1959-01-11      38     36.666667            NaN
# 1959-01-12      33     37.333333      35.416667
# 1959-01-13      55     39.000000      37.083333
# 1959-01-14      47     39.666667      38.333333
# 1959-01-15      45     40.833333      39.583333

# %% [markdown]
# #### Q4. Visualize the 6 and 12 period SMA data along with original data as shown below.
#
# **NOTE** - here, figsize = (12,8)

# %% [markdown]
# #### Q5. Split the data into train and test set with a split ratio of 80:20

# %%
# Out:
# Size of training data :  (292, 3)
# Size of test data :  (73, 3)

# %% [markdown]
# #### Q6. Perform the Simple Exponential Smoothing to model and forecast values

# %%
# Out:
# RMSE using Simple Exponential Smoothing :  7.538905192912766

# %% [markdown]
# #### Q7. Check the stationarity of data using Dickey-Fuller test.

# %%
# Out:
# p-value :  5.243412990149787e-05

# %% [markdown]
# #### Q8. Use auto_arima to find out p,d,q parameter values
#
# *NOTE* - Set seasonal argument to False here.

# %%
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(2,1,2)x(0,0,0,0) [intercept=True]; AIC=2463.066, BIC=2486.449, Time=2.888 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=2650.760, BIC=2658.555, Time=0.070 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=2565.234, BIC=2576.925, Time=0.267 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=2463.584, BIC=2475.275, Time=0.456 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=False]; AIC=2648.768, BIC=2652.665, Time=0.046 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=2460.539, BIC=2480.025, Time=2.177 seconds
# Near non-invertible roots for order (1, 1, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.998)
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=2461.271, BIC=2480.757, Time=1.226 seconds
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=2460.154, BIC=2475.743, Time=0.982 seconds
# ...

# %% [markdown]
# #### Q9. Fit an ARIMA model using the parameter values obtained through auto_arima.

# %%
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:               D.Births   No. Observations:                  291
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -983.479
# Method:                       css-mle   S.D. of innovations              7.071
# Date:                Thu, 04 Feb 2021   AIC                           1974.959
# Time:                        06:58:44   BIC                           1989.652
# Sample:                    01-02-1959   HQIC                          1980.845
#                          - 10-19-1959
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0316      0.014      2.230      0.026       0.004       0.059
# ar.L1.D.Births     0.0776      0.060      1.286      0.199      -0.041       0.196
# ...

# %%
# Out:
# RMSE using ARIMA :  43.41793490828498
