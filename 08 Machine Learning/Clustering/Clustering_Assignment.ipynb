# %% [markdown]
# #### Refer to the clustering_data.csv dataset and perform the following tasks.
#
# #### Q1. Import the dataset as a Pandas dataframe.

# %%
# Out:
#          x1         x2
# 0 -6.428841  10.141117
# 1  5.868679   5.201104
# 2 -0.376109   3.264279
# 3  2.166792   9.563005
# 4  5.095086   7.207527

# %% [markdown]
# #### Q2. Perform K-Means clustering using sklearn and find out the optimal value of k using Elbow method in a range 1 to 10.

# %% [markdown]
# #### Q3. Using the clustera after finding out optimal value of k.

# %% [markdown]
# #### Q4. Visualize the agglomerative clustering using dendrograms

# %% [markdown]
# #### Q5. Perform the Agglomerative clustering having 4 clusters using sklearn's implementation.

# %%
#clusters assigned to datapoints
# Out:
# array([2, 0, 3, 0, 0, 1, 0, 3, 0, 3, 2, 3, 0, 0, 2, 3, 0, 3, 1, 2, 1, 3,
#        0, 1, 2, 1, 1, 3, 0, 0, 2, 1, 0, 3, 3, 2, 1, 1, 1, 3, 1, 2, 2, 2,
#        3, 0, 2, 0, 1, 0, 3, 2, 0, 3, 1, 0, 0, 3, 2, 0, 1, 0, 1, 2, 0, 3,
#        1, 0, 0, 1, 0, 0, 1, 3, 1, 0, 0, 3, 2, 3, 3, 1, 0, 1, 3, 3, 3, 2,
#        0, 1, 1, 1, 1, 0, 0, 1, 0, 2, 1, 0, 3, 1, 0, 3, 0, 3, 1, 0, 1, 1,
#        0, 2, 2, 0, 1, 0, 2, 2, 0, 2, 0, 2, 3, 2, 3, 0, 2, 3, 1, 0, 2, 2,
#        3, 1, 1, 2, 0, 3, 0, 3, 1, 0, 1, 2, 2, 0, 0, 1, 2, 2, 2, 2, 3, 0,
#        3, 2, 0, 0, 0, 3, 0, 3, 3, 2, 1, 2, 3, 0, 2, 3, 0, 3, 2, 0, 0, 2,
#        0, 0, 1, 0, 2, 1, 1, 2, 1, 1, 1, 1, 1, 3, 1, 0, 0, 2, 1, 0, 0, 0,
#        1, 3], dtype=int64)

# %% [markdown]
# #### Q6. Visualize the clusters obtained from sklearn's agglomerative implementation as shown below.
