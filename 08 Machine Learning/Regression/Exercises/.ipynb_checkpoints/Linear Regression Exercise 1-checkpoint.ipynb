# %% [markdown]
# Refer to the **50_Startups.csv** file. The dataset contains **R&D**, **marketing**, **administration** spend of 50 different **Startups** along with the **profit** made by them.
#
# Perform the following tasks on this dataset.

# %%
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# #### Q1. Encode the State column using pandas get_dummmies() and avoid the chances of dummy trap by setting drop_first to True.

# %%
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0  165349.20       136897.80        471784.10  192261.83              0
# 1  162597.70       151377.59        443898.53  191792.06              0
# 2  153441.51       101145.55        407934.54  191050.39              1
# 3  144372.41       118671.85        383199.62  182901.99              0
# 4  142107.34        91391.77        366168.42  166187.94              1
#
#    State_New York
# 0               1
# 1               0
# 2               0
# 3               1
# 4               0

# %% [markdown]
# #### Q2. Fit a linear regression model to predict the Profit using R&D Spend and Marketing Spend.

# %%
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# #### Q3. Visualize the fitted model as shown below.
#
# **NOTE** - Use a step size of 1000 while creating a mesh grid of x and y values to plot the regression plane.

# %% [markdown]
# #### Q4. Calculate the RMSE of the fitted model.

# %%
# Out:
# RMSE : 8881.885892449169

# %% [markdown]
# #### Q5. Obtain the R-squared and Adjusted R-squared vales as follows.

# %%
# Out:
# R-Squared : 0.9504503015559764

# %%
# Out:
# Adjusted R-squared :  0.9483418037498477
